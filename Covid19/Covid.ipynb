# %%
import matplotlib.pyplot as plt
import Documents.GitHub.Cov2020.Covid19.LoadData as covid


w = covid.Covid(covid.GetData().data)

# w.createRegion("China")
# w.createRegion("US")
# w.createRegion("Canada")
# w.plotAreas(["Europe"])
# w.plotAreasPercent(["Poland", "Switzerland", "Italy", "US", "China", "Europe", "Singapore", "Taiwan", "Hubei, China"], maxSubplots=9)
# Out:
# Europe:: confirmed: 164342, deaths: 8604, recovered: 12784, active: 142954,
#
# China:: confirmed: 81439, deaths: 3274, recovered: 72814, active: 5351,
#
# US:: confirmed: 33276, deaths: 417, recovered: 178, active: 32681,
#
# Canada:: confirmed: 1470, deaths: 21, recovered: 10, active: 1439,

# %% [markdown]
# [All Europe Countries](https://github.com/rafallk/cov2020/blob/master/Covid19/Europe.ipynb)
