# %%
import matplotlib.pyplot as plt
import Documents.GitHub.Cov2020.Covid19.PresentEurope as covid
# Out:
# Input data Error ['Alberta', 'Canada'], name: ['Alberta', 'Canada']
# Input data Error ['British Columbia', 'Canada'], name: ['British Columbia', 'Canada']
# Input data Error ['Grand Princess', 'Canada'], name: ['Grand Princess', 'Canada']
# Input data Error ['Manitoba', 'Canada'], name: ['Manitoba', 'Canada']
# Input data Error ['New Brunswick', 'Canada'], name: ['New Brunswick', 'Canada']
# Input data Error ['Newfoundland and Labrador', 'Canada'], name: ['Newfoundland and Labrador', 'Canada']
# Input data Error ['Nova Scotia', 'Canada'], name: ['Nova Scotia', 'Canada']
# Input data Error ['Ontario', 'Canada'], name: ['Ontario', 'Canada']
# Input data Error ['Prince Edward Island', 'Canada'], name: ['Prince Edward Island', 'Canada']
# Input data Error ['Quebec', 'Canada'], name: ['Quebec', 'Canada']
# Input data Error ['Saskatchewan', 'Canada'], name: ['Saskatchewan', 'Canada']
# Input data Error ['Diamond Princess', 'Canada'], name: ['Diamond Princess', 'Canada']
# ...
